# %%
import pandas as pd
from pandas.io.json import json_normalize 
import os
import json 

def read_jsonl(path):
    data = []
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))

    return json_normalize(data)

def nice_name(row):
    if (row["model"] in ["RandomForestClassifier", "ExtraTreesClassifier", "GradientBoostingClassifier"]): 
        model_name = "{} with T = {}".format(row["model"], row["n_estimators"])
    elif row["model"] == "RiverModel":
        model_name = "{} with {}".format(row["model"], row["river_model"])
    elif (row["model"] == "BiasedProxEnsemble"):
        if int(row["max_trees"]) == 0:
            model_name = "{} with λ = {}".format(row["model"],row["l_reg"])
        else:
            model_name = "{} with T = {} and with λ = {}".format(row["model"], row["max_trees"], row["l_reg"])
    elif row["model"] == "JaxModel":
        model_name = "{} with T = {}".format(row["model"], row["n_trees"])
    else:
        model_name = "{} with T = {}".format(row["model"], row["max_trees"])
    
    return model_name

dataset = "magic"
dataset = os.path.join(dataset, "results")
all_subdirs = [os.path.join(dataset,d) for d in os.listdir(dataset) if os.path.isdir(os.path.join(dataset, d))]
print(all_subdirs)
latest_folder = max(all_subdirs, key=os.path.getmtime)

df = read_jsonl(os.path.join(latest_folder, "results.jsonl"))

df["nice_name"] = df.apply(nice_name, axis=1)
df = df.round(decimals = 3)
df
# Out:
# ['magic/results/08-12-2020-22:45:42']
#     X  Y bootstrap  experiment_id  idx      loss  max_depth  max_samples  \
# 0   X  Y      True              0  idx       mse          5         32.0
# 1   X  Y      True              6  idx       mse          5         32.0
# 2   X  Y       NaN              2  idx       mse          5          NaN
# 3   X  Y      True              9  idx       mse          5         32.0
# 4   X  Y       NaN              3  idx       mse          5          NaN
# 5   X  Y       NaN              8  idx       mse          5          NaN
# 6   X  Y       NaN              4  idx       mse          5          NaN
# 7   X  Y       NaN              7  idx       mse          5          NaN
# 8   X  Y       NaN             12  idx       mse          5          NaN
# 9   X  Y       NaN             13  idx       mse          5          NaN
# 10  X  Y       NaN             14  idx       mse          5          NaN
# 11  X  Y       NaN             11  idx       mse          5          NaN
# 12  X  Y      True             18  idx       mse          5         32.0
# 13  X  Y       NaN             16  idx       mse          5          NaN
# 14  X  Y       NaN             17  idx       mse          5          NaN
# 15  X  Y       NaN             21  idx  deviance          5          NaN
# 16  X  Y      True             22  idx       mse          5         32.0
# 17  X  Y       NaN             20  idx       mse          5          NaN
# 18  X  Y       NaN             19  idx       mse          5          NaN
# 19  X  Y       NaN             25  idx  deviance          5          NaN
# 20  X  Y       NaN             23  idx       mse          5          NaN
# 21  X  Y      True             27  idx       mse          5         32.0
# 22  X  Y       NaN             24  idx       mse          5          NaN
# 23  X  Y       NaN             28  idx       mse          5          NaN
# 24  X  Y       NaN             30  idx  deviance          5          NaN
# 25  X  Y       NaN             26  idx       mse          5          NaN
# 26  X  Y       NaN             29  idx       mse          5          NaN
# 27  X  Y       NaN              1  idx       mse          5          NaN
# 28  X  Y       NaN             15  idx       mse          5          NaN
# 29  X  Y       NaN             10  idx       mse          5          NaN
# 30  X  Y       NaN              5  idx       mse          5          NaN
#
#                          model  n_estimators  ... l_reg  max_trees  \
# 0         ExtraTreesClassifier          16.0  ...   NaN        NaN
# 1       RandomForestClassifier          32.0  ...   NaN        NaN
# 2                  SGDEnsemble           NaN  ...  0.06       16.0
# 3         ExtraTreesClassifier          32.0  ...   NaN        NaN
# 4                  SGDEnsemble           NaN  ...  0.06       32.0
# 5                  SGDEnsemble           NaN  ...  0.06       16.0
# 6           BiasedProxEnsemble           NaN  ...  0.04        0.0
# 7           BiasedProxEnsemble           NaN  ...  0.04        0.0
# 8                  SGDEnsemble           NaN  ...  0.06       32.0
# 9                  SGDEnsemble           NaN  ...  0.06       64.0
# 10                 SGDEnsemble           NaN  ...  0.06       64.0
# 11          BiasedProxEnsemble           NaN  ...  0.02        0.0
# 12      RandomForestClassifier          64.0  ...   NaN        NaN
# 13          BiasedProxEnsemble           NaN  ...  0.02        0.0
# 14          BiasedProxEnsemble           NaN  ...  0.06        0.0
# 15  GradientBoostingClassifier          16.0  ...   NaN        NaN
# 16      RandomForestClassifier          16.0  ...   NaN        NaN
# 17                 SGDEnsemble           NaN  ...  0.06       16.0
# 18          BiasedProxEnsemble           NaN  ...  0.02        0.0
# 19  GradientBoostingClassifier          32.0  ...   NaN        NaN
# 20                 SGDEnsemble           NaN  ...  0.06       32.0
# 21        ExtraTreesClassifier          64.0  ...   NaN        NaN
# 22          BiasedProxEnsemble           NaN  ...  0.04        0.0
# 23                 SGDEnsemble           NaN  ...  0.06       64.0
# 24  GradientBoostingClassifier          64.0  ...   NaN        NaN
# 25          BiasedProxEnsemble           NaN  ...  0.06        0.0
# 26          BiasedProxEnsemble           NaN  ...  0.06        0.0
# 27                  RiverModel           NaN  ...   NaN        NaN
# 28                    JaxModel           NaN  ...   NaN        NaN
# 29                    JaxModel           NaN  ...   NaN        NaN
# 30                    JaxModel           NaN  ...   NaN        NaN
#
#             mode     seed step_size  eval_loss  subsample  \
# 0            NaN      NaN       NaN        NaN        NaN
# 1            NaN      NaN       NaN        NaN        NaN
# 2          train  12345.0      0.50        NaN        NaN
# 3            NaN      NaN       NaN        NaN        NaN
# 4   fully-random  12345.0      0.50        NaN        NaN
# 5   fully-random  12345.0      0.50        NaN        NaN
# 6         random  12345.0      0.25        NaN        NaN
# 7          train  12345.0      0.25        NaN        NaN
# 8         random  12345.0      0.50        NaN        NaN
# 9   fully-random  12345.0      0.50        NaN        NaN
# 10         train  12345.0      0.50        NaN        NaN
# 11         train  12345.0      0.25        NaN        NaN
# 12           NaN      NaN       NaN        NaN        NaN
# 13  fully-random  12345.0      0.25        NaN        NaN
# 14        random  12345.0      0.25        NaN        NaN
# 15           NaN      NaN       NaN        mse      0.002
# 16           NaN      NaN       NaN        NaN        NaN
# 17        random  12345.0      0.50        NaN        NaN
# 18        random  12345.0      0.25        NaN        NaN
# 19           NaN      NaN       NaN        mse      0.002
# 20         train  12345.0      0.50        NaN        NaN
# 21           NaN      NaN       NaN        NaN        NaN
# 22  fully-random  12345.0      0.25        NaN        NaN
# 23        random  12345.0      0.50        NaN        NaN
# 24           NaN      NaN       NaN        mse      0.002
# 25         train  12345.0      0.25        NaN        NaN
# 26  fully-random  12345.0      0.25        NaN        NaN
# 27           NaN  12345.0       NaN        NaN        NaN
# 28           NaN  12345.0      0.10        NaN        NaN
# 29           NaN  12345.0      0.10        NaN        NaN
# 30           NaN  12345.0      0.10        NaN        NaN
#
#                             river_model  n_trees  \
# 0                                   NaN      NaN
# 1                                   NaN      NaN
# 2                                   NaN      NaN
# 3                                   NaN      NaN
# 4                                   NaN      NaN
# 5                                   NaN      NaN
# 6                                   NaN      NaN
# 7                                   NaN      NaN
# 8                                   NaN      NaN
# 9                                   NaN      NaN
# 10                                  NaN      NaN
# 11                                  NaN      NaN
# 12                                  NaN      NaN
# 13                                  NaN      NaN
# 14                                  NaN      NaN
# 15                                  NaN      NaN
# 16                                  NaN      NaN
# 17                                  NaN      NaN
# 18                                  NaN      NaN
# 19                                  NaN      NaN
# 20                                  NaN      NaN
# 21                                  NaN      NaN
# 22                                  NaN      NaN
# 23                                  NaN      NaN
# 24                                  NaN      NaN
# 25                                  NaN      NaN
# 26                                  NaN      NaN
# 27  ExtremelyFastDecisionTreeClassifier      NaN
# 28                                  NaN     16.0
# 29                                  NaN     32.0
# 30                                  NaN     64.0
#
#                                             nice_name
# 0                  ExtraTreesClassifier with T = 16.0
# 1                RandomForestClassifier with T = 32.0
# 2                           SGDEnsemble with T = 16.0
# 3                  ExtraTreesClassifier with T = 32.0
# 4                           SGDEnsemble with T = 32.0
# 5                           SGDEnsemble with T = 16.0
# 6                    BiasedProxEnsemble with λ = 0.04
# 7                    BiasedProxEnsemble with λ = 0.04
# 8                           SGDEnsemble with T = 32.0
# 9                           SGDEnsemble with T = 64.0
# 10                          SGDEnsemble with T = 64.0
# 11                   BiasedProxEnsemble with λ = 0.02
# 12               RandomForestClassifier with T = 64.0
# 13                   BiasedProxEnsemble with λ = 0.02
# 14                   BiasedProxEnsemble with λ = 0.06
# 15           GradientBoostingClassifier with T = 16.0
# 16               RandomForestClassifier with T = 16.0
# 17                          SGDEnsemble with T = 16.0
# 18                   BiasedProxEnsemble with λ = 0.02
# 19           GradientBoostingClassifier with T = 32.0
# 20                          SGDEnsemble with T = 32.0
# 21                 ExtraTreesClassifier with T = 64.0
# 22                   BiasedProxEnsemble with λ = 0.04
# 23                          SGDEnsemble with T = 64.0
# 24           GradientBoostingClassifier with T = 64.0
# 25                   BiasedProxEnsemble with λ = 0.06
# 26                   BiasedProxEnsemble with λ = 0.06
# 27  RiverModel with ExtremelyFastDecisionTreeClass...
# 28                             JaxModel with T = 16.0
# 29                             JaxModel with T = 32.0
# 30                             JaxModel with T = 64.0
#
# [31 rows x 50 columns]

# %%
df.columns
tabledf = df[["nice_name", "scores.mean_test_accuracy", "scores.mean_n_estimators", "scores.mean_n_nodes", "scores.mean_fit_time"]]
tabledf = tabledf.sort_values(by=['scores.mean_test_accuracy'], ascending = False)
tabledf
# Out:
#                                             nice_name  \
# 11                   BiasedProxEnsemble with λ = 0.02
# 7                    BiasedProxEnsemble with λ = 0.04
# 10                          SGDEnsemble with T = 64.0
# 25                   BiasedProxEnsemble with λ = 0.06
# 20                          SGDEnsemble with T = 32.0
# 9                           SGDEnsemble with T = 64.0
# 2                           SGDEnsemble with T = 16.0
# 27  RiverModel with ExtremelyFastDecisionTreeClass...
# 13                   BiasedProxEnsemble with λ = 0.02
# 15           GradientBoostingClassifier with T = 16.0
# 12               RandomForestClassifier with T = 64.0
# 4                           SGDEnsemble with T = 32.0
# 22                   BiasedProxEnsemble with λ = 0.04
# 21                 ExtraTreesClassifier with T = 64.0
# 3                  ExtraTreesClassifier with T = 32.0
# 1                RandomForestClassifier with T = 32.0
# 23                          SGDEnsemble with T = 64.0
# 18                   BiasedProxEnsemble with λ = 0.02
# 19           GradientBoostingClassifier with T = 32.0
# 26                   BiasedProxEnsemble with λ = 0.06
# 6                    BiasedProxEnsemble with λ = 0.04
# 0                  ExtraTreesClassifier with T = 16.0
# 16               RandomForestClassifier with T = 16.0
# 5                           SGDEnsemble with T = 16.0
# 14                   BiasedProxEnsemble with λ = 0.06
# 8                           SGDEnsemble with T = 32.0
# 17                          SGDEnsemble with T = 16.0
# 28                             JaxModel with T = 16.0
# 29                             JaxModel with T = 32.0
# 30                             JaxModel with T = 64.0
# 24           GradientBoostingClassifier with T = 64.0
#
#     scores.mean_test_accuracy  scores.mean_n_estimators  scores.mean_n_nodes  \
# 11                     85.073                     321.0              20223.0
# 7                      84.326                     210.6              13267.8
# 10                     84.310                      64.0               4032.0
# 25                     84.147                     158.8              10004.4
# 20                     83.227                      32.0               2016.0
# 9                      82.339                      64.0               4032.0
# 2                      81.450                      16.0               1008.0
# 27                     81.129                       1.0               1498.2
# 13                     80.446                     153.2               9651.6
# 15                     80.304                      16.0                503.2
# 12                     80.193                      64.0                980.0
# 4                      79.384                      32.0               2016.0
# 22                     79.231                     103.6               6526.8
# 21                     79.158                      64.0               1884.8
# 3                      78.411                      32.0                927.6
# 1                      78.280                      32.0                483.2
# 23                     78.259                      64.0               4032.0
# 18                     78.069                     191.4              12058.2
# 19                     78.012                      32.0                993.2
# 26                     77.375                      58.2               3666.6
# 6                      77.091                     141.0               8883.0
# 0                      76.665                      16.0                475.2
# 16                     76.492                      16.0                244.4
# 5                      76.434                      16.0               1008.0
# 14                     76.239                      88.6               5581.8
# 8                      75.325                      32.0               2016.0
# 17                     72.233                      16.0               1008.0
# 28                     64.835                      16.0               1008.0
# 29                     64.835                      32.0               2016.0
# 30                     64.835                      64.0               4032.0
# 24                     63.921                      64.0               1838.8
#
#     scores.mean_fit_time
# 11               119.954
# 7                 92.308
# 10                54.238
# 25                77.625
# 20                49.548
# 9                 52.202
# 2                 43.192
# 27               563.218
# 13                66.914
# 15                 0.073
# 12                 0.157
# 4                 44.223
# 22                60.166
# 21                 0.141
# 3                  0.054
# 1                  0.080
# 23                55.902
# 18                87.162
# 19                 0.145
# 26                50.826
# 6                 70.737
# 0                  0.043
# 16                 0.042
# 5                 45.172
# 14                65.410
# 8                 47.299
# 17                46.746
# 28              1004.365
# 29              1720.104
# 30              3161.506
# 24                 0.254

# %%
import numpy as np
pd.set_option('expand_frame_repr', True)
pd.set_option('max_colwidth', 110)
#tabledf = df[["nice_name", "scores.mean_test_accuracy", "scores.mean_n_estimators", "scores.mean_n_nodes", "scores.mean_fit_time"]]
dff = df.sort_values(by=['scores.mean_test_accuracy'], ascending = False)

#dff["nice_name"].head(n=10)
methods = ["BiasedProxEnsemble with λ = 0.02", "SGDEnsemble with T = 64.0", "RiverModel with ExtremelyFastDecisionTreeClassifier", "JaxModel with T = 16.0"]
traindfs = []
for m in methods:
    #print("M: ", m)
    experiment_path = dff.loc[ df["nice_name"] == m ]["out_path"].values[0]
    traindf = None
    
    # TODO not hardcode 5 here
    accuracies = []
    losses = []
    num_nodes = []
    total_item_cnt = None
    for i in range(5):
        path = os.path.join(experiment_path, str(i), "training.jsonl")
        tdf = read_jsonl(path)
        losses.append(tdf["test_loss"].values)
        accuracies.append(tdf["test_accuracy"].values)
        num_nodes.append(tdf["test_num_nodes"].values)
        if total_item_cnt is None:
            total_item_cnt = tdf["total_item_cnt"]
    

    # TODO add std 
    d = {
        "total_item_cnt":total_item_cnt,
        "test_loss":np.mean(losses, axis=0),
        "test_accuracy":np.mean(accuracies, axis=0),
        "test_num_nodes":np.mean(num_nodes, axis=0),
    }
    traindf = pd.DataFrame(d)
    
    traindfs.append(traindf)

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# https://colorbrewer2.org/#type=qualitative&scheme=Paired&n=9
paired = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a','#ffff99','#b15928'] 
colors = {}
for m,c in zip(methods, paired):
    colors[m] = c

fig = make_subplots(rows=3, cols=1, subplot_titles=["Magic"], horizontal_spacing = 0.03, vertical_spacing = 0.02)

for tdf, m in zip(traindfs, methods):
    fig = fig.add_trace(go.Scatter(x=tdf["total_item_cnt"], y = tdf["test_loss"], mode="lines", name = m, marker=dict(color = colors[m])), row = 1, col = 1)
    fig = fig.add_trace(go.Scatter(x=tdf["total_item_cnt"], y = tdf["test_accuracy"], mode="lines", name = m, showlegend = False, marker=dict(color = colors[m])), row = 2, col = 1)
    fig = fig.add_trace(go.Scatter(x=tdf["total_item_cnt"], y = tdf["test_num_nodes"], mode="lines", name = m, showlegend = False, marker=dict(color = colors[m])), row = 3, col = 1)

fig.update_xaxes(title_text="Number of items", row=3, col=1, title_font = {"size": 16})
fig.update_yaxes(title_text="Test loss", row=1, col=1, title_font = {"size": 16})
fig.update_yaxes(title_text="Test accuracy", row=2, col=1, title_font = {"size": 16})
fig.update_yaxes(title_text="Numb of nodes", row=3, col=1, title_font = {"size": 16})

fig.update_layout(
    template="simple_white",
    legend=dict(orientation="h",yanchor="bottom",y=-0.1,xanchor="left",x=0.15),
    margin={'l': 5, 'r': 20, 't': 20, 'b': 5},
    height=900, width=1100
)
fig.show()
# Out:
# <div>                            <div id="9d4668a7-9262-4ae1-9ff7-69a313f7b864" class="plotly-graph-div" style="height:900px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d4668a7-9262-4ae1-9ff7-69a313f7b864")) {                    Plotly.newPlot(                        "9d4668a7-9262-4ae1-9ff7-69a313f7b864",                        [{"marker": {"color": "#a6cee3"}, "mode": "lines", "name": "BiasedProxEnsemble with \u03bb = 0.02", "type": "scatter", "x": [1056, 2112, 3168, 4224, 5280, 6336, 7392, 8448, 9504, 10560, 11616, 12672, 13728, 14784, 15215, 16271, 17327, 18383, 19439, 20495, 21551, 22607, 23663, 24719, 25775, 26831, 27887, 28943, 29999, 30430, 31486, 32542, 33598, 34654, 35710, 36766, 37822, 38878, 39934, 40990, 42046, 43102, 44158, 45214, 45645, 46701, 47757, 48813, 49869, 50925, 51981, 53037, 54093, 55149, 56205, 57261, 58317, 59373, 60429, 60860, 61916, 62972, 64028, 65084, 66140, 67196, 68252, 69308, 70364, 71420, 72476, 73532, 74588, 75644, 76075, 77131, 78187, 79243, 80299, 81355, 82411, 83467, 84523, 85579, 86635, 87691, 88747, 89803, 90859, 91290, 92346, 93402, 94458, 95514, 96570, 97626, 98682, 99738, 100794, 101850, 102906, 103962, 105018, 106074, 106505, 107561, 108617, 109673, 110729, 111785, 112841, 113897, 114953, 116009, 117065, 118121, 119177, 120233, 121289, 121720, 122776, 123832, 124888, 125944, 127000, 128056, 129112, 130168, 131224, 132280, 133336, 134392, 135448, 136504, 136935, 137991, 139047, 140103, 141159, 142215, 143271, 144327, 145383, 146439, 147495, 148551, 149607, 150663, 151719, 152150, 153206, 154262, 155318, 156374, 157430, 158486, 159542, 160598, 161654, 162710, 163766, 164822, 165878, 166934, 167365, 168421, 169477, 170533, 171589, 172645, 173701, 174757, 175813, 176869, 177925, 178981, 180037, 181093, 182149, 182580, 183636, 184692, 185748, 186804, 187860, 188916, 189972, 191028, 192084, 193140, 194196, 195252, 196308, 197364, 197795, 198851, 199907, 200963, 202019, 203075, 204131, 205187, 206243, 207299, 208355, 209411, 210467, 211523, 212579, 213010, 214066, 215122, 216178, 217234, 218290, 219346, 220402, 221458, 222514, 223570, 224626, 225682, 226738, 227794, 228225, 229281, 230337, 231393, 232449, 233505, 234561, 235617, 236673, 237729, 238785, 239841, 240897, 241953, 243009, 243440, 244496, 245552, 246608, 247664, 248720, 249776, 250832, 251888, 252944, 254000, 255056, 256112, 257168, 258224, 258655, 259711, 260767, 261823, 262879, 263935, 264991, 266047, 267103, 268159, 269215, 270271, 271327, 272383, 273439, 273870, 274926, 275982, 277038, 278094, 279150, 280206, 281262, 282318, 283374, 284430, 285486, 286542, 287598, 288654, 289085, 290141, 291197, 292253, 293309, 294365, 295421, 296477, 297533, 298589, 299645, 300701, 301757, 302813, 303869, 304300, 305356, 306412, 307468, 308524, 309580, 310636, 311692, 312748, 313804, 314860, 315916, 316972, 318028, 319084, 319515, 320571, 321627, 322683, 323739, 324795, 325851, 326907, 327963, 329019, 330075, 331131, 332187, 333243, 334299, 334730, 335786, 336842, 337898, 338954, 340010, 341066, 342122, 343178, 344234, 345290, 346346, 347402, 348458, 349514, 349945, 351001, 352057, 353113, 354169, 355225, 356281, 357337, 358393, 359449, 360505, 361561, 362617, 363673, 364729, 365160, 366216, 367272, 368328, 369384, 370440, 371496, 372552, 373608, 374664, 375720, 376776, 377832, 378888, 379944, 380375, 381431, 382487, 383543, 384599, 385655, 386711, 387767, 388823, 389879, 390935, 391991, 393047, 394103, 395159, 395590, 396646, 397702, 398758, 399814, 400870, 401926, 402982, 404038, 405094, 406150, 407206, 408262, 409318, 410374, 410805, 411861, 412917, 413973, 415029, 416085, 417141, 418197, 419253, 420309, 421365, 422421, 423477, 424533, 425589, 426020, 427076, 428132, 429188, 430244, 431300, 432356, 433412, 434468, 435524, 436580, 437636, 43 ...
